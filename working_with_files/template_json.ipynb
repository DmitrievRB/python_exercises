# %%
import json

with open("visit.json", encoding="utf8") as myFile:
    strfile = myFile.read()
    template = json.loads(strfile)
print(template)
print(type(template))
# Out:
# {'firstname': 'Иван', 'lastname': 'Иванов', 'isAlive': True, 'age': 32, 'address': {'street Address': 'Нейбута 32', 'city': 'Владивосток', 'state': '', 'postal code': ''}, 'phone Numbers': [{'type': 'mob', 'number': ' 123-333-4455 '}, {'type': 'office', 'number': ' 123 111-4567 '}], 'children': [], 'spouse': None}
# <class 'dict'>

# %%
import json
template = {
"firstname":"Иван",
"lastname": "Иванова",
"isAlive": True,
"age":32,
"address":{
"street Address": "Нейбута 32",
"city": "Владивосток",
"state":"",
"postal code":""
},
"phone Numbers":[
{
"type":"mob",
"number":" 123-333-4455 "
},
{
"type":"office",
"number":" 123 111-4567 "
}
],
"children":[],
"spouse": None
}
with open("to1_visit.json","w",encoding="utf8") as f:
    json.dump(template,f,ensure_ascii= False,indent=4)
with open("to1_visit.json",encoding="utf8") as f:
    print(f.read())
# Out:
# {
#     "firstname": "Иван",
#     "lastname": "Иванова",
#     "isAlive": true,
#     "age": 32,
#     "address": {
#         "street Address": "Нейбута 32",
#         "city": "Владивосток",
#         "state": "",
#         "postal code": ""
#     },
#     "phone Numbers": [
#         {
#             "type": "mob",
#             "number": " 123-333-4455 "
#         },
#         {
#             "type": "office",
#             "number": " 123 111-4567 "
#         }
#     ],
#     "children": [],
#     "spouse": null
# }

# %% [markdown]
# ![QAP_4.1.1_new.jpg](attachment:QAP_4.1.1_new.jpg)
